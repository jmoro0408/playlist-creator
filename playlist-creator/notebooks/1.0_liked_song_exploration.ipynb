# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_filepath = r"/Users/jamesmoro/Documents/Python/playlist-creator/playlist-creator/data/liked_songs_df.pkl"

# %%
raw_df = pd.read_pickle(data_filepath)

# %%
df = raw_df.copy()

# %%
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.533   0.826   10    -9.246     0       0.0580       0.02080
# 1         0.627   0.478    3   -11.919     1       0.1260       0.64500
# 2         0.445   0.665    4    -7.764     0       0.0380       0.12700
# 3         0.618   0.651    9    -7.811     1       0.0417       0.00808
# 4         0.361   0.901    4    -4.133     0       0.0443       0.00152
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.001880    0.3480    0.531   88.934  audio_features
# 1          0.012300    0.0800    0.382   74.594  audio_features
# 2          0.024200    0.0943    0.146  169.048  audio_features
# 3          0.688000    0.6460    0.965  169.995  audio_features
# 4          0.000246    0.2860    0.481  144.974  audio_features
#
#                        id                                   uri  \
# 0  4gad1qhsqNL63n9OyCDsjL  spotify:track:4gad1qhsqNL63n9OyCDsjL
# ...

# %%
df.describe()
# Out:
#        danceability     energy        key   loudness      mode  speechiness  \
# count     20.000000  20.000000  20.000000  20.000000  20.00000    20.000000
# mean       0.551150   0.725050   4.550000  -7.707500   0.65000     0.049355
# std        0.153997   0.151993   3.575869   3.040921   0.48936     0.022103
# min        0.254000   0.335000   0.000000 -13.745000   0.00000     0.025100
# 25%        0.438000   0.651750   1.750000  -9.539250   0.00000     0.037850
# 50%        0.576500   0.733000   4.000000  -7.592500   1.00000     0.042600
# 75%        0.631000   0.826250   7.500000  -5.589250   1.00000     0.052600
# max        0.853000   0.959000  11.000000  -3.385000   1.00000     0.126000
#
#        acousticness  instrumentalness   liveness   valence       tempo  \
# count     20.000000         20.000000  20.000000  20.00000   20.000000
# mean       0.212657          0.176058   0.188610   0.56695  125.172650
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      20 non-null     float64
#  1   energy            20 non-null     float64
#  2   key               20 non-null     int64
#  3   loudness          20 non-null     float64
#  4   mode              20 non-null     int64
#  5   speechiness       20 non-null     float64
#  6   acousticness      20 non-null     float64
#  7   instrumentalness  20 non-null     float64
#  8   liveness          20 non-null     float64
#  9   valence           20 non-null     float64
#  10  tempo             20 non-null     float64
#  11  type              20 non-null     object
#  12  id                20 non-null     object
#  13  uri               20 non-null     object
#  14  track_href        20 non-null     object
#  15  analysis_url      20 non-null     object
# ...

# %%
df.shape
# Out:
# (20, 20)
